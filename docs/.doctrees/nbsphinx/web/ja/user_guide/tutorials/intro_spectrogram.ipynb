# %% [markdown]
# # SpectrogramList と SpectrogramDict のチュートリアル
#
# このノートブックでは、`gwexpy` で新しく導入された `SpectrogramList` および `SpectrogramDict` クラスの使い方を紹介します。
#
# これらのクラスは、複数のスペクトログラムデータ（`gwpy.spectrogram.Spectrogram`）をまとめて管理し、一括して処理（クロップ、再ビン化、プロットなど）を行うためのコンテナです。
# 時系列データを扱う `TimeSeriesList` / `TimeSeriesDict` と似たインターフェースを持っていますが、2次元データ（時間 × 周波数）を扱う点が特徴です。

# %%
import matplotlib.pyplot as plt

from gwexpy.noise.wave import gaussian, sine
from gwexpy.spectrogram import SpectrogramDict, SpectrogramList
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 from gwexpy.noise.wave import gaussian, sine
#       4 from gwexpy.spectrogram import SpectrogramDict, SpectrogramList
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/__init__.py:51
#      46 warnings.filterwarnings(
#      47     "ignore", message="Protobuf gencode version", category=UserWarning
#      48 )
#      50 # Subpackages are available via namespace
# ---> 51 from . import (
#      52     astro,
#      53     detector,
#      54     frequencyseries,
#      55     interop,
#      56     io,
#      57     noise,
#      58     plot,
#      59     segments,
#      60     signal,
#      61     spectral,
#      62     spectrogram,
#      63     table,
#      64     time,
#      65     timeseries,
#      66     types,
#      67 )
#      68 from ._version import __version__
#      69 from .fields import FieldDict, FieldList, ScalarField, TensorField, VectorField
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/__init__.py:36
#      32 # Register I/O readers on import
#      33 # Dynamic import from gwpy (PEP 562)
#      34 import gwpy.timeseries as _gwpy_timeseries
# ---> 36 from . import io as _io  # noqa: F401
#      39 def __getattr__(name):
#      40     try:
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/io/__init__.py:11
#       8 from __future__ import annotations
#      10 # Readers are registered on import
# ---> 11 from . import (
#      12     ats,  # noqa: F401
#      13     dttxml,  # noqa: F401
#      14     gbd,  # noqa: F401
#      15     sdb,  # noqa: F401
#      16     seismic,  # noqa: F401
#      17     stubs,  # noqa: F401
#      18     tdms,  # noqa: F401
#      19     wav,  # noqa: F401
#      20     win,  # noqa: F401
#      21 )
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/io/ats.py:221
#     218 # -- Registration
#     220 for fmt in ["ats"]:
# --> 221     io_registry.register_reader(
#     222         fmt, TimeSeriesDict, read_timeseriesdict_ats, force=True
#     223     )
#     224     io_registry.register_reader(fmt, TimeSeries, read_timeseries_ats, force=True)
#     225     io_registry.register_reader(
#     226         fmt,
#     227         TimeSeriesMatrix,
#     228         lambda *a, **k: read_timeseriesdict_ats(*a, **k).to_matrix(),
#     229         force=True,
#     230     )
#
# AttributeError: module 'gwpy.io.registry' has no attribute 'register_reader'

# %% [markdown]
# ## 1. データの準備
#
# まずはデモ用のスペクトログラムデータを作成します。
# ここでは、異なる周波数のサイン波を含む時系列データを生成し、それを `spectrogram()` メソッドで変換して使用します。

# %%
# サンプルデータの作成
duration = 20  # 秒
sample_rate = 128  # Hz

# 10Hz, 30Hz, 50Hz のサイン波 (+ノイズ) を作成
noise_amp = 0.1


def make_signal(freq, name):
    s = sine(duration=duration, sample_rate=sample_rate, frequency=freq, amplitude=1.0)
    n = gaussian(duration=duration, sample_rate=sample_rate, std=noise_amp)
    ts = s + n
    ts.name = name
    ts.override_unit("strain")
    return ts


ts1 = make_signal(10, "Signal 10Hz")
ts2 = make_signal(30, "Signal 30Hz")
ts3 = make_signal(50, "Signal 50Hz")

# スペクトログラムの計算 (stride=2s, fftlength=1s)
# nproc=1 を指定してシリアル実行による安定化を図ります
spec1 = ts1.spectrogram(2, fftlength=1, overlap=0.5, nproc=1)
spec2 = ts2.spectrogram(2, fftlength=1, overlap=0.5, nproc=1)
spec3 = ts3.spectrogram(2, fftlength=1, overlap=0.5, nproc=1)

print("Spectrogram shape:", spec1.shape)
print("Time range:", spec1.xspan)
print("Freq range:", spec1.yspan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      14     ts.override_unit("strain")
#      15     return ts
# ---> 18 ts1 = make_signal(10, "Signal 10Hz")
#      19 ts2 = make_signal(30, "Signal 30Hz")
#      20 ts3 = make_signal(50, "Signal 50Hz")
#
# Cell In[2], line 10, in make_signal(freq, name)
#       9 def make_signal(freq, name):
# ---> 10     s = sine(duration=duration, sample_rate=sample_rate, frequency=freq, amplitude=1.0)
#      11     n = gaussian(duration=duration, sample_rate=sample_rate, std=noise_amp)
#      12     ts = s + n
#
# NameError: name 'sine' is not defined

# %% [markdown]
# ## 2. SpectrogramList の基本操作
#
# `SpectrogramList` はリストのように振る舞いますが、格納できるのは `Spectrogram` オブジェクトのみです。
# 初期化時にリストを渡すか、`append()` メソッドで追加します。

# %%
# リストの作成
spec_list = SpectrogramList([spec1, spec2])

# 追加
spec_list.append(spec3)

print(f"List length: {len(spec_list)}")
print(f"Items: {[s.name for s in spec_list]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # リストの作成
# ----> 2 spec_list = SpectrogramList([spec1, spec2])
#       4 # 追加
#       5 spec_list.append(spec3)
#
# NameError: name 'SpectrogramList' is not defined

# %% [markdown]
# ### バッチ処理: 時間軸の切り出し (`crop`)
#
# リスト内のすべてのスペクトログラムに対して、一括で時間軸の切り出しを行います。
# **注意:** スペクトログラムはデータ量が大きいため、クロップなどの操作は元のデータを変更せず、新しいオブジェクト（コピー）を返すことがあります。

# %%
# 5秒〜15秒の範囲を切り出し
cropped_list = spec_list.crop(5, 15)

print("Original range:", spec_list[0].xspan)
print("Cropped range:", cropped_list[0].xspan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 5秒〜15秒の範囲を切り出し
# ----> 2 cropped_list = spec_list.crop(5, 15)
#       4 print("Original range:", spec_list[0].xspan)
#       5 print("Cropped range:", cropped_list[0].xspan)
#
# NameError: name 'spec_list' is not defined

# %% [markdown]
# ### バッチ処理: 周波数軸の切り出し (`crop_frequencies`)
#
# gwpyの `Spectrogram` に互換性のあるメソッドがあればそれを使用し、なければ周波数軸を指定してフィルタリングを行います。

# %%
# 0Hz 〜 40Hz の範囲を切り出し
freq_cropped = spec_list.crop_frequencies(0, 40)

print("Original yspan:", spec_list[0].yspan)
print("Cropped yspan:", freq_cropped[0].yspan)
# 50Hzの信号を含んでいた3つ目の要素も範囲外の部分はカットされます
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # 0Hz 〜 40Hz の範囲を切り出し
# ----> 2 freq_cropped = spec_list.crop_frequencies(0, 40)
#       4 print("Original yspan:", spec_list[0].yspan)
#       5 print("Cropped yspan:", freq_cropped[0].yspan)
#
# NameError: name 'spec_list' is not defined

# %% [markdown]
# ## 3. SpectrogramDict の利用
#
# 名前（キー）付きで管理したい場合は `SpectrogramDict` が便利です。

# %%
spec_dict = SpectrogramDict({"low_freq": spec1, "mid_freq": spec2, "high_freq": spec3})

print("Keys:", list(spec_dict.keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spec_dict = SpectrogramDict({"low_freq": spec1, "mid_freq": spec2, "high_freq": spec3})
#       3 print("Keys:", list(spec_dict.keys()))
#
# NameError: name 'SpectrogramDict' is not defined

# %% [markdown]
# ## 4. 可視化 (`plot`)
#
# リストや辞書の `.plot()` メソッドを呼ぶと、含まれるすべてのスペクトログラムをまとめてプロットできます。
# 内部では `gwpy.plot.Plot` を使用しています。

# %%
# 一括プロット
# sharex=True, sharey=True にすると軸を共有して比較しやすくなります
plot = spec_dict.plot(figsize=(12, 8), sharex=True, sharey=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 一括プロット
#       2 # sharex=True, sharey=True にすると軸を共有して比較しやすくなります
# ----> 3 plot = spec_dict.plot(figsize=(12, 8), sharex=True, sharey=True)
#       4 plt.show()
#
# NameError: name 'spec_dict' is not defined

# %% [markdown]
# ## 5. マトリックス形式への変換とDeep Learning連携
#
# `to_matrix()` を使用すると、各スペクトログラムを積み重ねた 3次元配列 `(Channels, Time, Frequency)` を持つ `SpectrogramMatrix` オブジェクトを作成できます。
#
# これは機械学習モデル（PyTorch, TensorFlowなど）への入力を作成する際に非常に便利です。

# %%
matrix = spec_list.to_matrix()

print("Matrix Type:", type(matrix))
print("Matrix Shape:", matrix.shape)
print("  (N_channels, N_time_steps, N_freq_bins)")

# 属性へのアクセス
print("Time axis shape:", matrix.times.shape)
print("Freq axis shape:", matrix.frequencies.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 matrix = spec_list.to_matrix()
#       3 print("Matrix Type:", type(matrix))
#       4 print("Matrix Shape:", matrix.shape)
#
# NameError: name 'spec_list' is not defined

# %% [markdown]
# PyTorchやCuPyがインストールされていれば、そのままTensor等に変換可能です。
#
# ```python
# # PyTorch Tensorへの変換
# # tensor = matrix.to_torch()
# ```

# %% [markdown]
# ## まとめ
#
# これで `SpectrogramList` と `SpectrogramDict` の基本的な使い方の紹介を終わります。
# 大量のスペクトログラムデータを一括で前処理したり、比較プロットを行う際にぜひ活用してください。
