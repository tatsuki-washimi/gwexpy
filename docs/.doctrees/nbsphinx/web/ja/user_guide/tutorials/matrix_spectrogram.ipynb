# %% [markdown]
# # SpectrogramMatrix Tutorial
#
# このノートブックでは `gwexpy` の `SpectrogramMatrix` クラスの基本的な使い方を紹介します。
#
# `SpectrogramMatrix` は、複数の `gwpy.spectrogram.Spectrogram` オブジェクトを 3次元 (Batch, Time, Frequency) の行列として効率的に扱うためのクラスです。`numpy.ndarray` を継承しており、高速な数値計算や PyTorch/CuPy との連携が可能です。

# %%
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np

from gwexpy.timeseries import TimeSeriesMatrix

# 乱数シードの固定
np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 5 from gwexpy.timeseries import TimeSeriesMatrix
#       7 # 乱数シードの固定
#       8 np.random.seed(42)
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/__init__.py:51
#      46 warnings.filterwarnings(
#      47     "ignore", message="Protobuf gencode version", category=UserWarning
#      48 )
#      50 # Subpackages are available via namespace
# ---> 51 from . import (
#      52     astro,
#      53     detector,
#      54     frequencyseries,
#      55     interop,
#      56     io,
#      57     noise,
#      58     plot,
#      59     segments,
#      60     signal,
#      61     spectral,
#      62     spectrogram,
#      63     table,
#      64     time,
#      65     timeseries,
#      66     types,
#      67 )
#      68 from ._version import __version__
#      69 from .fields import FieldDict, FieldList, ScalarField, TensorField, VectorField
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/__init__.py:36
#      32 # Register I/O readers on import
#      33 # Dynamic import from gwpy (PEP 562)
#      34 import gwpy.timeseries as _gwpy_timeseries
# ---> 36 from . import io as _io  # noqa: F401
#      39 def __getattr__(name):
#      40     try:
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/io/__init__.py:11
#       8 from __future__ import annotations
#      10 # Readers are registered on import
# ---> 11 from . import (
#      12     ats,  # noqa: F401
#      13     dttxml,  # noqa: F401
#      14     gbd,  # noqa: F401
#      15     sdb,  # noqa: F401
#      16     seismic,  # noqa: F401
#      17     stubs,  # noqa: F401
#      18     tdms,  # noqa: F401
#      19     wav,  # noqa: F401
#      20     win,  # noqa: F401
#      21 )
#
# File ~/miniconda3/envs/docs/lib/python3.11/site-packages/gwexpy/timeseries/io/ats.py:221
#     218 # -- Registration
#     220 for fmt in ["ats"]:
# --> 221     io_registry.register_reader(
#     222         fmt, TimeSeriesDict, read_timeseriesdict_ats, force=True
#     223     )
#     224     io_registry.register_reader(fmt, TimeSeries, read_timeseries_ats, force=True)
#     225     io_registry.register_reader(
#     226         fmt,
#     227         TimeSeriesMatrix,
#     228         lambda *a, **k: read_timeseriesdict_ats(*a, **k).to_matrix(),
#     229         force=True,
#     230     )
#
# AttributeError: module 'gwpy.io.registry' has no attribute 'register_reader'

# %% [markdown]
# ## 1. データの準備

# %%
rng = np.random.default_rng(0)

# サンプル設定
n = 512
dt = (1 / 128) * u.s
t0 = 0 * u.s

t = (np.arange(n) * dt).to_value(u.s)

tone50 = np.sin(2 * np.pi * 50 * t)
tone20 = np.sin(2 * np.pi * 20 * t + 0.3)

data = np.empty((2, 2, n), dtype=float)
data[0, 0] = 0.5 * tone50 + 0.05 * rng.normal(size=n)
data[0, 1] = 0.5 * tone20 + 0.05 * rng.normal(size=n)
data[1, 0] = 0.3 * tone50 + 0.3 * tone20 + 0.05 * rng.normal(size=n)
data[1, 1] = 0.2 * tone50 - 0.4 * tone20 + 0.05 * rng.normal(size=n)

units = np.full((2, 2), u.V)
names = [["ch00", "ch01"], ["ch10", "ch11"]]
channels = [["X:A", "X:B"], ["Y:A", "Y:B"]]

tsm = TimeSeriesMatrix(
    data,
    dt=dt,
    t0=t0,
    units=units,
    names=names,
    channels=channels,
    rows={"r0": {"name": "row0"}, "r1": {"name": "row1"}},
    cols={"c0": {"name": "col0"}, "c1": {"name": "col1"}},
    name="demo",
)

display(tsm)
tsm.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      20 names = [["ch00", "ch01"], ["ch10", "ch11"]]
#      21 channels = [["X:A", "X:B"], ["Y:A", "Y:B"]]
# ---> 23 tsm = TimeSeriesMatrix(
#      24     data,
#      25     dt=dt,
#      26     t0=t0,
#      27     units=units,
#      28     names=names,
#      29     channels=channels,
#      30     rows={"r0": {"name": "row0"}, "r1": {"name": "row1"}},
#      31     cols={"c0": {"name": "col0"}, "c1": {"name": "col1"}},
#      32     name="demo",
#      33 )
#      35 display(tsm)
#      36 tsm.plot()
#
# NameError: name 'TimeSeriesMatrix' is not defined

# %% [markdown]
# ## 2. SpectrogramMatrix の作成
#
# `SpectrogramList` の `to_matrix()` メソッドを使用すると、全てのスペクトログラムが一つの `SpectrogramMatrix` にスタックされます。
# これにより、形状が `(N, Time, Frequency)` の3次元配列が得られます。

# %%
spec_matrix = tsm.spectrogram(2, fftlength=0.5, overlap=0.25)

print("Type:", type(spec_matrix))
print("Shape:", spec_matrix.shape)  # (Batch, Time, Freq)
spec_matrix.plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 spec_matrix = tsm.spectrogram(2, fftlength=0.5, overlap=0.25)
#       3 print("Type:", type(spec_matrix))
#       4 print("Shape:", spec_matrix.shape)  # (Batch, Time, Freq)
#
# NameError: name 'tsm' is not defined

# %% [markdown]
# ### 属性へのアクセス
# `SpectrogramMatrix` は元のスペクトログラムの時間軸や周波数軸の情報を保持しています。

# %%
print("Time axis (first 5):", spec_matrix.times[:5])
print("Freq axis (first 5):", spec_matrix.frequencies[:5])
print("Unit:", spec_matrix.unit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("Time axis (first 5):", spec_matrix.times[:5])
#       2 print("Freq axis (first 5):", spec_matrix.frequencies[:5])
#       3 print("Unit:", spec_matrix.unit)
#
# NameError: name 'spec_matrix' is not defined

# %% [markdown]
# ## 3. 数値計算と統計
#
# `SpectrogramMatrix` は `numpy.ndarray` のサブクラスであるため、Numpy の関数をそのまま適用できます。
# また、`mean()` などのメソッドも利用可能です。
#
# 例えば、全チャネル（バッチ方向）の平均スペクトログラムを計算してみましょう。

# %%
# axis=0 (Batch軸) で平均を取る
mean_spectrogram_data = spec_matrix.mean(axis=0)

print("Mean Data Shape:", mean_spectrogram_data.shape)
# 結果は (Time, Freq) の2次元配列になります
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # axis=0 (Batch軸) で平均を取る
# ----> 2 mean_spectrogram_data = spec_matrix.mean(axis=0)
#       4 print("Mean Data Shape:", mean_spectrogram_data.shape)
#       5 # 結果は (Time, Freq) の2次元配列になります
#
# NameError: name 'spec_matrix' is not defined

# %% [markdown]
# ## 4. プロット
#
# `plot()` メソッドを使用すると、データを可視化できます。
# 3次元データ（Batch, Time, Freq）に対して `plot()` を呼び出すと、デフォルトでは**バッチ方向の平均**がプロットされます。
# これは複数のイベントの平均的な特徴を確認するのに便利です。

# %%
plot = spec_matrix.plot(title="Mean Spectrogram (All Channels)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot = spec_matrix.plot(title="Mean Spectrogram (All Channels)")
#       2 plt.show()
#
# NameError: name 'spec_matrix' is not defined

# %% [markdown]
# 特定のチャネルだけをプロットしたい場合は、`monitor` 引数にインデックスを指定します。

# %%
# 最初のチャネル (Channel_0) をプロット
plot0 = spec_matrix.plot(monitor=0, title="Channel 0 Spectrogram")
plot0.show()

# 5番目のチャネル (Channel_5) をプロット
plot5 = spec_matrix.plot(monitor=3, title="Channel 5 Spectrogram")
plot5.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 最初のチャネル (Channel_0) をプロット
# ----> 2 plot0 = spec_matrix.plot(monitor=0, title="Channel 0 Spectrogram")
#       3 plot0.show()
#       5 # 5番目のチャネル (Channel_5) をプロット
#
# NameError: name 'spec_matrix' is not defined

# %% [markdown]
# ## 5. 外部ライブラリとの連携
#
# 機械学習やGPU計算のために、PyTorch や CuPy のテンソルへ簡単に変換できます。

# %%
# PyTorch Tensor への変換
try:
    import torch

    _ = torch
    torch_tensor = spec_matrix.to_torch()
    print("PyTorch Tensor:", type(torch_tensor))
    print("Shape:", torch_tensor.shape)
except ImportError:
    print("PyTorch is not installed.")

# CuPy Array への変換（CUDA環境がある場合）
from gwexpy.interop import is_cupy_available

if is_cupy_available():
    cupy_array = spec_matrix.to_cupy()
    print("CuPy Array:", type(cupy_array))
    print("Shape:", cupy_array.shape)
else:
    print("CuPy is not installed or GPU driver is not working.")
# Out:
# PyTorch is not installed.
# CuPy is not installed or GPU driver is not working.

# %% [markdown]
# ## まとめ
#
# - **`SpectrogramMatrix`** は `SpectrogramList.to_matrix()` で作成できます。
# - 3次元配列 `(Batch, Time, Freq)` としてデータを保持します。
# - `mean()` や `plot()` メソッドで、データの集約や可視化が簡単に行えます。
# - `to_torch()` などでディープラーニングフレームワークへデータを渡す際の中間形式としても有用です。
