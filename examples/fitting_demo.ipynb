# %% [markdown]
# # gwexpy.fitting: iminuit ベースのフィッティング機能
#
# このノートブックでは、`gwexpy.fitting` モジュールを使用して、`TimeSeries` や `FrequencySeries` データに対して簡単にフィッティングを行う方法を紹介します。
# バックエンドには `iminuit` を使用しており、誤差を考慮した最小二乗法フィッティングが可能です。

# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
import numpy as np
import matplotlib.pyplot as plt
from gwexpy.timeseries import TimeSeries
from gwexpy.frequencyseries import FrequencySeries
from gwexpy.plot import Plot
from gwexpy.fitting import enable_fitting_monkeypatch; enable_fitting_monkeypatch()  # これを呼び出すことで .fit() メソッドが有効になります

# %% [markdown]
# ## 1. データの準備
#
# ここでは、ガウス関数にノイズを加えたダミーデータを作成します。

# %%
# モデル関数の定義 (ガウス関数)
def gaussian(x, a, mu, sigma):
    return a * np.exp(-(x - mu)**2 / (2 * sigma**2))

# ダミーデータの生成
np.random.seed(42)
x = np.linspace(-5, 5, 100)
true_params = {'a': 10, 'mu': 0.5, 'sigma': 1.2}
y_true = gaussian(x, **true_params)
y_noise = y_true + np.random.normal(0, 1.0, size=len(x))

# TimeSeries オブジェクトの作成
ts = TimeSeries(y_noise, dt=0.1, name='Noisy Gaussian', unit='V')
ts.plot(title='Noisy Data for Gaussian Fit');
# Out:
# <Plot size 1200x400 with 1 Axes>

# %% [markdown]
# ## 2. フィッティングの実行
#
# `ts.fit()` メソッドを使用してフィッティングを行います。
# 引数にはモデル関数と、パラメータの初期値 `p0` を指定します。

# %%
# フィッティング
# p0 で初期値を指定します
result = ts.fit(gaussian, p0={'a': 5, 'mu': 5, 'sigma': 1})

# 結果の表示
display(result)
# Out:
# <table>
#     <tr>
#         <th colspan="2" style="text-align:center" title="Minimizer"> Migrad </th>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Minimum value of function"> FCN = 80.1 (χ²/ndof = 0.8) </td>
#         <td style="text-align:center" title="Total number of function and (optional) gradient evaluations"> Nfcn = 87 </td>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Estimated distance to minimum and goal"> EDM = 2.58e-06 (Goal: 0.0002) </td>
#         <td style="text-align:center" title="Total run time of algorithms">  </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Valid Minimum </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below EDM threshold (goal x 10) </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> No parameters at limit </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below call limit </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Hesse ok </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Covariance accurate </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th title="Variable name"> Name </th>
#         <th title="Value of parameter"> Value </th>
#         <th title="Hesse error"> Hesse Error </th>
#         <th title="Minos lower error"> Minos Error- </th>
#         <th title="Minos upper error"> Minos Error+ </th>
#         <th title="Lower limit of the parameter"> Limit- </th>
#         <th title="Upper limit of the parameter"> Limit+ </th>
#         <th title="Is the parameter fixed in the fit"> Fixed </th>
#     </tr>
#     <tr>
#         <th> 0 </th>
#         <td> a </td>
#         <td> 10.05 </td>
#         <td> 0.27 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <td> mu </td>
#         <td> 5.49 </td>
#         <td> 0.04 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 2 </th>
#         <td> sigma </td>
#         <td> 1.159 </td>
#         <td> 0.035 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th> a </th>
#         <th> mu </th>
#         <th> sigma </th>
#     </tr>
#     <tr>
#         <th> a </th>
#         <td> 0.072 </td>
#         <td style="background-color:rgb(249,249,250);color:black"> -0.0000 <strong>(-0.005)</strong> </td>
#         <td style="background-color:rgb(176,176,250);color:black"> -0.0054 <strong>(-0.569)</strong> </td>
#     </tr>
#     <tr>
#         <th> mu </th>
#         <td style="background-color:rgb(249,249,250);color:black"> -0.0000 <strong>(-0.005)</strong> </td>
#         <td> 0.00129 </td>
#         <td style="background-color:rgb(250,249,249);color:black"> 0.0000 <strong>(0.008)</strong> </td>
#     </tr>
#     <tr>
#         <th> sigma </th>
#         <td style="background-color:rgb(176,176,250);color:black"> -0.0054 <strong>(-0.569)</strong> </td>
#         <td style="background-color:rgb(250,249,249);color:black"> 0.0000 <strong>(0.008)</strong> </td>
#         <td> 0.00124 </td>
#     </tr>
# </table><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="288pt" viewBox="0 0 360 288" xmlns="http://www.w3.org/2000/svg" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-12-23T02:29:05.154711</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.8, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 360 288
# L 360 0
# L 0 0
# z
# " style="fill: #ffffff"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 23.80024 266.63726
# L 356.99976 266.63726
# L 356.99976 3.00024
# L 23.80024 3.00024
# z
# " style="fill: #ffffff"/>
#    </g>
#    <g id="LineCollection_1">
#     <path d="M 38.945673 216.286625
# L 38.945673 184.147172
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 42.005356 226.488502
# L 42.005356 194.349049
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 45.065039 213.855513
# L 45.065039 181.71606
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 48.124723 199.784832
# L 48.124723 167.645379
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 51.184406 228.016378
# L 51.184406 195.876925
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 54.24409 228.007834
# L 54.24409 195.868381
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 57.303773 198.856283
# L 57.303773 166.71683
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 60.363456 211.885437
# L 60.363456 179.745984
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 63.42314 231.740444
# L 63.42314 199.600992
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 66.482823 215.447706
# L 66.482823 183.308253
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 69.542507 231.573513
# L 69.542507 199.43406
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 72.60219 231.557116
# L 72.60219 199.417663
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 75.661873 220.113512
# L 75.661873 187.974059
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 78.721557 254.653759
# L 78.721557 222.514306
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 81.78124 251.503882
# L 81.78124 219.364429
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 84.840923 232.661006
# L 84.840923 200.521553
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 87.900607 239.695205
# L 87.900607 207.555752
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 90.96029 218.106005
# L 90.96029 185.966552
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 94.019974 237.413214
# L 94.019974 205.273761
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 97.079657 245.095743
# L 97.079657 212.95629
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 100.13934 198.32162
# L 100.13934 166.182167
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 103.199024 224.849978
# L 103.199024 192.710525
# " clip-path="url(#pa35bca36de)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 106.258707 219.334263
# L 106.258707 187.19481
# " clip-path="url(#pa35bca36de)" style="fill: non

# %% [markdown]
# ## 3. 結果の取得とプロット
#
# `FitResult` オブジェクトから、ベストフィットパラメータや誤差、Chi2 値などを取得できます。
# また、`.plot()` メソッドで簡単に結果を可視化できます。

# %%
print("Best Fit Parameters:", result.params)
print("Errors:", result.errors)
print("Chi2:", result.chi2)
print("NDOF:", result.ndof)

# プロット
fig, ax = plt.subplots(figsize=(10, 6))
result.plot(ax=ax, color='red', linewidth=2)
ax.set_title("Gaussian Fit Demo")
ax.set_xlabel("Time [s]")
ax.set_ylabel("Amplitude")
plt.show()
# Out:
# Best Fit Parameters: {'a': 10.052918089674625, 'mu': 5.4945648176033375, 'sigma': 1.1593703774689315}
# Errors: {'a': 0.2683127955313306, 'mu': 0.035979235655612826, 'sigma': 0.03522684863175708}
# Chi2: 80.09851473366132
# NDOF: 97

# %% [markdown]
# ## 3. 文字列によるモデル指定
#
# モデル関数を定義する代わりに、定義済みのモデル名を文字列で指定することもできます。
# 現在サポートされているモデル: `'gaus'`, `'exp'`, `'pol0'`, `'pol1'`, ... `'pol9'`, `'landau'` など。
#
# 以下は `'gaus'` を指定してフィッティングを行う例です。

# %%
# 文字列 'gaus' を指定してフィッティング
# 注意: 定義済みモデルのパラメータ名はモデルごとに決まっています (Gaussianの場合は A, mu, sigma)
result_str = ts.fit('gaus', 
                    p0={'A': 10, 'mu': 5, 'sigma': 1.0}, 
                    x_range=(2, 8)
                   )

# 結果の表示
display(result_str);
# Out:
# <table>
#     <tr>
#         <th colspan="2" style="text-align:center" title="Minimizer"> Migrad </th>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Minimum value of function"> FCN = 53.14 (χ²/ndof = 0.9) </td>
#         <td style="text-align:center" title="Total number of function and (optional) gradient evaluations"> Nfcn = 69 </td>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Estimated distance to minimum and goal"> EDM = 8.43e-05 (Goal: 0.0002) </td>
#         <td style="text-align:center" title="Total run time of algorithms">  </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Valid Minimum </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below EDM threshold (goal x 10) </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> No parameters at limit </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below call limit </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Hesse ok </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Covariance accurate </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th title="Variable name"> Name </th>
#         <th title="Value of parameter"> Value </th>
#         <th title="Hesse error"> Hesse Error </th>
#         <th title="Minos lower error"> Minos Error- </th>
#         <th title="Minos upper error"> Minos Error+ </th>
#         <th title="Lower limit of the parameter"> Limit- </th>
#         <th title="Upper limit of the parameter"> Limit+ </th>
#         <th title="Is the parameter fixed in the fit"> Fixed </th>
#     </tr>
#     <tr>
#         <th> 0 </th>
#         <td> A </td>
#         <td> 10.05 </td>
#         <td> 0.27 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <td> mu </td>
#         <td> 5.49 </td>
#         <td> 0.04 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 2 </th>
#         <td> sigma </td>
#         <td> 1.16 </td>
#         <td> 0.04 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th> A </th>
#         <th> mu </th>
#         <th> sigma </th>
#     </tr>
#     <tr>
#         <th> A </th>
#         <td> 0.0734 </td>
#         <td style="background-color:rgb(248,248,250);color:black"> -0.0001 <strong>(-0.012)</strong> </td>
#         <td style="background-color:rgb(175,175,250);color:black"> -0.0058 <strong>(-0.580)</strong> </td>
#     </tr>
#     <tr>
#         <th> mu </th>
#         <td style="background-color:rgb(248,248,250);color:black"> -0.0001 <strong>(-0.012)</strong> </td>
#         <td> 0.00131 </td>
#         <td style="background-color:rgb(250,246,246);color:black"> 0.0000 <strong>(0.027)</strong> </td>
#     </tr>
#     <tr>
#         <th> sigma </th>
#         <td style="background-color:rgb(175,175,250);color:black"> -0.0058 <strong>(-0.580)</strong> </td>
#         <td style="background-color:rgb(250,246,246);color:black"> 0.0000 <strong>(0.027)</strong> </td>
#         <td> 0.00135 </td>
#     </tr>
# </table><?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="288pt" viewBox="0 0 360 288" xmlns="http://www.w3.org/2000/svg" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-12-23T02:29:05.415454</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.8, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 288
# L 360 288
# L 360 0
# L 0 0
# z
# " style="fill: #ffffff"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 23.80024 266.63726
# L 356.99976 266.63726
# L 356.99976 3.00024
# L 23.80024 3.00024
# z
# " style="fill: #ffffff"/>
#    </g>
#    <g id="LineCollection_1">
#     <path d="M 38.945673 208.254969
# L 38.945673 174.374183
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 44.079718 236.220649
# L 44.079718 202.339862
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 49.213763 230.406088
# L 49.213763 196.525302
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 54.347808 254.653759
# L 54.347808 220.772973
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 59.481853 238.49085
# L 59.481853 204.610063
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 64.615898 225.890025
# L 64.615898 192.009239
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 69.749943 245.481618
# L 69.749943 211.600831
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 74.883988 217.509986
# L 74.883988 183.6292
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 80.018033 231.579802
# L 80.018033 197.699015
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 85.152078 223.478226
# L 85.152078 189.59744
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 90.286123 225.428027
# L 90.286123 191.547241
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 95.420168 180.087818
# L 95.420168 146.207032
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 100.554213 207.431049
# L 100.554213 173.550262
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 105.688258 220.339821
# L 105.688258 186.459034
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 110.822303 183.176259
# L 110.822303 149.295472
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 115.956348 211.946186
# L 115.956348 178.065399
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 121.090393 181.353562
# L 121.090393 147.472776
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 126.224438 211.210346
# L 126.224438 177.329559
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 131.358483 193.162587
# L 131.358483 159.281801
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 136.492528 159.556669
# L 136.492528 125.675882
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 141.626573 142.255739
# L 141.626573 108.374953
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 146.760618 143.46328
# L 146.760618 109.582494
# " clip-path="url(#pce707a0976)" style="fill: none; stroke: #000000; stroke-width: 1.5"/>
#     <path d="M 151.894663 139.749083
# L 151.894663 105.868297
# " clip-path="url(#p

# %% [markdown]
# ## 4. 複素数フィッティング (伝達関数)
#
# 伝達関数などの複素数データに対してもフィッティングを行えます。
# コスト関数として $\chi^2 = \sum (Re_{diff})^2 + \sum (Im_{diff})^2$ を最小化し、実部と虚部を同時にフィットします。
# 結果のプロットは自動的にボード線図（振幅・位相）になります。

# %%
import numpy as np

# 1. 複素数モデルの定義 (単純な極)
def pole_model(f, A, f0, Q):
    # H(f) = A / (1 + i * Q * (f/f0 - f0/f))
    # Low-pass filter like but simplified. Let's use standard mechanical transfer function:
    # H(f) = A / [ (f0^2 - f^2) + i * (f0 * f / Q) ]
    omega = 2 * np.pi * f
    omega0 = 2 * np.pi * f0
    return A / ( (omega0**2 - omega**2) + 1j * (omega0 * omega / Q) )

# 2. データ生成
f = np.linspace(10, 1000, 1000)
p_true = {'A': 1e7, 'f0': 300, 'Q': 10}
data_clean = pole_model(f, **p_true)

# ノイズ付加 (実部・虚部独立)
np.random.seed(0)
noise_re = np.random.normal(0, 5, len(f))
noise_im = np.random.normal(0, 5, len(f))
data_noisy = data_clean + 0.2*noise_re + 0.2j * noise_im

# FrequencySeries 作成
fs = FrequencySeries(data_noisy, frequencies=f, name='Transfer Function')
plot = Plot(fs.abs(), fs.real, fs.imag, xscale='log', yscale='symlog', alpha=0.8)
plt.legend(['|H(f)|','Re(H(f))','Im(H(f))'])
plt.title('Noisy Transfer Function Data')
# Out:
# Text(0.5, 1.0, 'Noisy Transfer Function Data')
# /home/washimi/miniforge3/envs/ws-base/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   func(*args, **kwargs)
# /home/washimi/miniforge3/envs/ws-base/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   fig.canvas.print_figure(bytes_io, **kw)
# <Plot size 640x480 with 1 Axes>

# %%
# 3. フィッティング
print("Fit Start...")
# 初期値はずらしておく
result_complex = fs.fit(pole_model, 
                        p0={'A': 0.8e7, 'f0': 320, 'Q': 8})

# 結果表示
display(result_complex)

# 4. プロット (ボード線図)
# 自動的に振幅と位相のプロットになります
result_complex.bode_plot();
# Out:
# Fit Start...
# /home/washimi/work/gwexpy/gwexpy/fitting/core.py:32: FutureWarning: make_func_code is deprecated: Use of ``func_code`` attribute to declare parameters is deprecated. Use ``_parameters`` instead, which is a dict of parameter names to limits.
#   self.func_code = make_func_code(params)
# <table>
#     <tr>
#         <th colspan="2" style="text-align:center" title="Minimizer"> Migrad </th>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Minimum value of function"> FCN = 1907 (χ²/ndof = 1.0) </td>
#         <td style="text-align:center" title="Total number of function and (optional) gradient evaluations"> Nfcn = 102 </td>
#     </tr>
#     <tr>
#         <td style="text-align:left" title="Estimated distance to minimum and goal"> EDM = 1.21e-09 (Goal: 0.0002) </td>
#         <td style="text-align:center" title="Total run time of algorithms">  </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Valid Minimum </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below EDM threshold (goal x 10) </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> No parameters at limit </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Below call limit </td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Hesse ok </td>
#         <td style="text-align:center;background-color:#92CCA6;color:black"> Covariance accurate </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th title="Variable name"> Name </th>
#         <th title="Value of parameter"> Value </th>
#         <th title="Hesse error"> Hesse Error </th>
#         <th title="Minos lower error"> Minos Error- </th>
#         <th title="Minos upper error"> Minos Error+ </th>
#         <th title="Lower limit of the parameter"> Limit- </th>
#         <th title="Upper limit of the parameter"> Limit+ </th>
#         <th title="Is the parameter fixed in the fit"> Fixed </th>
#     </tr>
#     <tr>
#         <th> 0 </th>
#         <td> A </td>
#         <td> 10.09e6 </td>
#         <td> 0.07e6 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <td> f0 </td>
#         <td> 300.24 </td>
#         <td> 0.11 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
#     <tr>
#         <th> 2 </th>
#         <td> Q </td>
#         <td> 9.99 </td>
#         <td> 0.10 </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#         <td>  </td>
#     </tr>
# </table><table>
#     <tr>
#         <td></td>
#         <th> A </th>
#         <th> f0 </th>
#         <th> Q </th>
#     </tr>
#     <tr>
#         <th> A </th>
#         <td> 5.4e+09 </td>
#         <td style="background-color:rgb(250,235,235);color:black"> 795.222 <strong>(0.099)</strong> </td>
#         <td style="background-color:rgb(158,158,250);color:black"> -5.296459e3 <strong>(-0.707)</strong> </td>
#     </tr>
#     <tr>
#         <th> f0 </th>
#         <td style="background-color:rgb(250,235,235);color:black"> 795.222 <strong>(0.099)</strong> </td>
#         <td> 0.0118 </td>
#         <td style="background-color:rgb(245,245,250);color:black"> -0.000 <strong>(-0.035)</strong> </td>
#     </tr>
#     <tr>
#         <th> Q </th>
#         <td style="background-color:rgb(158,158,250);color:black"> -5.296459e3 <strong>(-0.707)</strong> </td>
#         <td style="background-color:rgb(245,245,250);color:black"> -0.000 <strong>(-0.035)</strong> </td>
#         <td> 0.0104 </td>
#     </tr>
# </table>

# %% [markdown]
# ## 5. MCMC 解析 (emcee)
#
# `iminuit` で得られた最尤推定値を初期値として、`emcee` を用いた MCMC (Markov Chain Monte Carlo) 解析を行うことができます。
#
# > **Note:** この機能を使用するには `emcee` と `corner` がインストールされている必要があります。

# %%
# MCMCの実行
# n_walkers: walkerの数, n_steps: ステップ数, burn_in: 捨て去る初期ステップ数
try:
    sampler = result_complex.run_mcmc(n_walkers=32, n_steps=1000, burn_in=200)
    
    # コーナープロットの作成 (事後分布の可視化)
    # 真値（または最尤推定値）を青線で表示します
    result_complex.plot_corner()
    
except ImportError as e:
    print(e)
except Exception as e:
    print(f"MCMC Error: {e}")
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 810.06it/s]

# %% [markdown]
# ## 新しい共通モデルの使用例
#
# `gwexpy.fitting.models` に追加された `power_law` と `damped_oscillation` の使用例です。

# %%
from gwexpy.fitting.models import power_law, damped_oscillation

# Power law
x = np.logspace(0, 2, 100)
y = power_law(x, A=10, alpha=-1.5) * (1 + 0.1 * np.random.normal(size=len(x)))
fs = FrequencySeries(y, frequencies=x)
res_pl = fs.fit('power_law', p0={'A': 5, 'alpha': -1})
print("Power law alpha:", res_pl.params['alpha'])

# Damped oscillation
t = np.linspace(0, 1, 1000)
y_osc = damped_oscillation(t, A=1, tau=0.3, f=10) + 0.05 * np.random.normal(size=len(t))
ts_osc = TimeSeries(y_osc, times=t)
res_osc = ts_osc.fit('damped_oscillation', p0={'A': 0.5, 'tau': 0.5, 'f': 12})
print("Damped oscillation frequency:", res_osc.params['f'])
